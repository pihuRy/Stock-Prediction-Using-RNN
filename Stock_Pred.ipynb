# %%
import pandas as pd

# %%
df = pd.read_csv('/content/TECHM STOCK - Sheet1.csv')

# %%
df.head()
# Out:
#                   Date     Open     High      Low    Close   Volume
# 0  10/29/2018 15:30:00  1808.70  1877.95  1784.35  1871.00  2609483
# 1  10/30/2018 15:30:00  1867.00  1909.40  1845.00  1894.80  2404883
# 2  10/31/2018 15:30:00  1900.00  1943.90  1875.45  1938.15  2769190
# 3   11/1/2018 15:30:00  1943.65  1944.35  1901.30  1935.75  2769759
# 4   11/2/2018 15:30:00  1934.20  1954.60  1905.00  1913.45  1818635

# %%
df.tail()
# Out:
#                     Date    Open     High      Low    Close   Volume
# 1343   4/9/2024 15:30:00  3984.0  4015.85  3925.05  3946.55  1876992
# 1344  4/10/2024 15:30:00  3956.4  3990.20  3918.00  3980.75  2101965
# 1345  4/12/2024 15:30:00  3971.0  4013.35  3945.50  4001.40  4354821
# 1346  4/15/2024 15:30:00  4001.4  4064.20  3919.05  3941.20  4200329
# 1347  4/16/2024 15:30:00  3902.0  3928.70  3862.85  3872.80  3051407

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1348 entries, 0 to 1347
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1348 non-null   object
#  1   Open    1348 non-null   float64
#  2   High    1348 non-null   float64
#  3   Low     1348 non-null   float64
#  4   Close   1348 non-null   float64
#  5   Volume  1348 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 63.3+ KB

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1348 entries, 0 to 1347
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1348 non-null   datetime64[ns]
#  1   Open    1348 non-null   float64
#  2   High    1348 non-null   float64
#  3   Low     1348 non-null   float64
#  4   Close   1348 non-null   float64
#  5   Volume  1348 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 63.3 KB

# %%
df['Date'] = df['Date'].dt.date

# %%
df['Date']
# Out:
# 0       2018-10-29
# 1       2018-10-30
# 2       2018-10-31
# 3       2018-11-01
# 4       2018-11-02
#            ...
# 1343    2024-04-09
# 1344    2024-04-10
# 1345    2024-04-12
# 1346    2024-04-15
# 1347    2024-04-16
# Name: Date, Length: 1348, dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Year'] = df['Date'].dt.year

# %%
df.head()
# Out:
#         Date     Open     High      Low    Close   Volume  Year
# 0 2018-10-29  1808.70  1877.95  1784.35  1871.00  2609483  2018
# 1 2018-10-30  1867.00  1909.40  1845.00  1894.80  2404883  2018
# 2 2018-10-31  1900.00  1943.90  1875.45  1938.15  2769190  2018
# 3 2018-11-01  1943.65  1944.35  1901.30  1935.75  2769759  2018
# 4 2018-11-02  1934.20  1954.60  1905.00  1913.45  1818635  2018

# %%
df.describe()
# Out:
#                                 Date         Open         High          Low  \
# count                           1348  1348.000000  1348.000000  1348.000000
# mean   2021-07-22 07:28:39.881305600  2927.260349  2955.511832  2897.320772
# min              2018-10-29 00:00:00  1559.700000  1685.450000  1506.050000
# 25%              2020-03-12 18:00:00  2189.450000  2210.950000  2166.437500
# 50%              2021-07-22 12:00:00  3170.500000  3199.300000  3133.975000
# 75%              2022-12-01 06:00:00  3435.000000  3466.162500  3412.962500
# max              2024-04-16 00:00:00  4215.250000  4254.750000  4177.000000
# std                              NaN   677.551571   680.223932   675.000813
#
#              Close        Volume         Year
# count  1348.000000  1.348000e+03  1348.000000
# mean   2926.293991  2.794128e+06  2021.063056
# min    1636.350000  2.244050e+05  2018.000000
# 25%    2186.612500  1.746246e+06  2020.000000
# 50%    3167.550000  2.374614e+06  2021.000000
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
plt.plot(df['Date'],df['Open'], c='blue', alpha=0.5, marker='.', label='Open')
plt.plot(df['Date'],df['Close'], c='red', alpha=0.5, marker='.', label='Close')
plt.plot(df['Date'],df['High'],c='green', alpha=0.5, marker='x', label='High')
plt.plot(df['Date'],df['Low'],c='yellow', alpha=0.5, marker='.', label='Low')

plt.xlabel("Date",fontsize=18,color='Red')
plt.ylabel("Market Price",fontsize=18,color='Red')
plt.legend(loc='upper left', fontsize=16)
plt.show()

# %%
df['Year'] = df['Date'].dt.year

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1348 entries, 0 to 1347
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1348 non-null   datetime64[ns]
#  1   Open    1348 non-null   float64
#  2   High    1348 non-null   float64
#  3   Low     1348 non-null   float64
#  4   Close   1348 non-null   float64
#  5   Volume  1348 non-null   int64
#  6   Year    1348 non-null   int32
# dtypes: datetime64[ns](1), float64(4), int32(1), int64(1)
# memory usage: 68.6 KB

# %%
df.head()
# Out:
#         Date     Open     High      Low    Close   Volume  Year
# 0 2018-10-29  1808.70  1877.95  1784.35  1871.00  2609483  2018
# 1 2018-10-30  1867.00  1909.40  1845.00  1894.80  2404883  2018
# 2 2018-10-31  1900.00  1943.90  1875.45  1938.15  2769190  2018
# 3 2018-11-01  1943.65  1944.35  1901.30  1935.75  2769759  2018
# 4 2018-11-02  1934.20  1954.60  1905.00  1913.45  1818635  2018

# %%
train_set = df[df['Year']<2022]
test_set = df[df['Year']>=2023]

# %%
train_set
# Out:
#           Date     Open     High      Low    Close   Volume  Year
# 0   2018-10-29  1808.70  1877.95  1784.35  1871.00  2609483  2018
# 1   2018-10-30  1867.00  1909.40  1845.00  1894.80  2404883  2018
# 2   2018-10-31  1900.00  1943.90  1875.45  1938.15  2769190  2018
# 3   2018-11-01  1943.65  1944.35  1901.30  1935.75  2769759  2018
# 4   2018-11-02  1934.20  1954.60  1905.00  1913.45  1818635  2018
# ..         ...      ...      ...      ...      ...      ...   ...
# 780 2021-12-27  3671.00  3700.00  3653.10  3696.10  1534135  2021
# 781 2021-12-28  3710.00  3725.00  3693.85  3706.55  1456218  2021
# 782 2021-12-29  3692.25  3719.95  3685.00  3694.70  1456923  2021
# 783 2021-12-30  3681.35  3740.00  3680.00  3733.75  1966475  2021
# 784 2021-12-31  3742.80  3760.00  3731.30  3738.35  1207141  2021
#
# [785 rows x 7 columns]

# %%
test_set
# Out:
#            Date    Open     High      Low    Close   Volume  Year
# 1032 2023-01-02  3261.0  3266.85  3235.20  3261.45   709547  2023
# 1033 2023-01-03  3252.0  3320.00  3245.30  3311.35  1245178  2023
# 1034 2023-01-04  3306.7  3327.35  3286.20  3314.65  1231668  2023
# 1035 2023-01-05  3330.2  3337.30  3281.95  3311.10  1826057  2023
# 1036 2023-01-06  3300.0  3301.55  3200.00  3211.55  2488376  2023
# ...         ...     ...      ...      ...      ...      ...   ...
# 1343 2024-04-09  3984.0  4015.85  3925.05  3946.55  1876992  2024
# 1344 2024-04-10  3956.4  3990.20  3918.00  3980.75  2101965  2024
# 1345 2024-04-12  3971.0  4013.35  3945.50  4001.40  4354821  2024
# 1346 2024-04-15  4001.4  4064.20  3919.05  3941.20  4200329  2024
# 1347 2024-04-16  3902.0  3928.70  3862.85  3872.80  3051407  2024
#
# [316 rows x 7 columns]

# %%
train_set = train_set.iloc[:,[0,2]]
test_set = test_set.iloc[:,[0,2]]

# %%
train_set.head()
# Out:
#         Date     High
# 0 2018-10-29  1877.95
# 1 2018-10-30  1909.40
# 2 2018-10-31  1943.90
# 3 2018-11-01  1944.35
# 4 2018-11-02  1954.60

# %%
test_set.head()
# Out:
#            Date     High
# 1032 2023-01-02  3266.85
# 1033 2023-01-03  3320.00
# 1034 2023-01-04  3327.35
# 1035 2023-01-05  3337.30
# 1036 2023-01-06  3301.55

# %%
test_set.tail()
# Out:
#            Date     High
# 1343 2024-04-09  4015.85
# 1344 2024-04-10  3990.20
# 1345 2024-04-12  4013.35
# 1346 2024-04-15  4064.20
# 1347 2024-04-16  3928.70

# %%
train_set = train_set.set_index('Date')
train_set.head()
# Out:
#                High
# Date
# 2018-10-29  1877.95
# 2018-10-30  1909.40
# 2018-10-31  1943.90
# 2018-11-01  1944.35
# 2018-11-02  1954.60

# %%
train_set.shape
# Out:
# (785, 1)

# %%
test_set = test_set.set_index('Date')
test_set.head()
# Out:
#                High
# Date
# 2023-01-02  3266.85
# 2023-01-03  3320.00
# 2023-01-04  3327.35
# 2023-01-05  3337.30
# 2023-01-06  3301.55

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
model = scaler.fit(train_set)
scaled_train_set = model.transform(train_set)
scaled_train_set
# Out:
# array([[0.08353403],
#        [0.09718154],
#        [0.11215257],
#        [0.11234785],
#        [0.11679576],
#        [0.10497082],
#        [0.10937534],
#        [0.11998525],
#        [0.11310725],
#        [0.11002625],
#        [0.10607737],
#        [0.09266853],
#        [0.09301569],
#        [0.09629196],
#        [0.09397036],
#        [0.08053983],
#        [0.07036386],
#        [0.07574475],
#        [0.0921912 ],
#        [0.1317234 ],
#        [0.13519495],
#        [0.13259129],
#        [0.13215735],
#        [0.14491527],
#        [0.14430775],
#        [0.14387381],
#        [0.13818916],
#        [0.14127015],
#        [0.14083621],
#        [0.14604352],
#        [0.14938489],
#        [0.13604114],
#        [0.1386231 ],
#        [0.13736466],
#        [0.12990084],
#        [0.12560481],
#        [0.11479963],
#        [0.10998286],
#        [0.10256243],
#        [0.1111979 ],
#        [0.10178134],
#        [0.09700796],
#        [0.09744191],
# ...

# %%
scaler = MinMaxScaler()
model = scaler.fit(test_set)
scaled_test_set = model.transform(test_set)
type(scaled_test_set)
# Out:
# numpy.ndarray

# %%
scaled_train_set_df = pd.DataFrame(scaled_train_set)
scaled_train_set_df
# Out:
#             0
# 0    0.083534
# 1    0.097182
# 2    0.112153
# 3    0.112348
# 4    0.116796
# ..        ...
# 780  0.874200
# 781  0.885048
# 782  0.882857
# 783  0.891558
# 784  0.900236
#
# [785 rows x 1 columns]

# %%
scaled_test_set_df = pd.DataFrame(scaled_test_set)
scaled_test_set_df
# Out:
#             0
# 0    0.134749
# 1    0.181301
# 2    0.187738
# 3    0.196453
# 4    0.165141
# ..        ...
# 311  0.790760
# 312  0.768294
# 313  0.788570
# 314  0.833107
# 315  0.714430
#
# [316 rows x 1 columns]

# %%
train_set
# Out:
#                High
# Date
# 2018-10-29  1877.95
# 2018-10-30  1909.40
# 2018-10-31  1943.90
# 2018-11-01  1944.35
# 2018-11-02  1954.60
# ...             ...
# 2021-12-27  3700.00
# 2021-12-28  3725.00
# 2021-12-29  3719.95
# 2021-12-30  3740.00
# 2021-12-31  3760.00
#
# [785 rows x 1 columns]

# %%
scaled_train_set_df.shape
# Out:
# (785, 1)

# %%
import numpy as np
X_train = []
y_train = []

for i in range(5,785):
  X_train.append(scaled_train_set_df.iloc[i-5:i,0])
  y_train.append(scaled_train_set_df.iloc[i,0])

X_train, y_train = np.array(X_train), np.array(y_train)

# %%
X_train
# Out:
# array([[0.08353403, 0.09718154, 0.11215257, 0.11234785, 0.11679576],
#        [0.09718154, 0.11215257, 0.11234785, 0.11679576, 0.10497082],
#        [0.11215257, 0.11234785, 0.11679576, 0.10497082, 0.10937534],
#        ...,
#        [0.84677472, 0.8613986 , 0.87636963, 0.87419992, 0.88504849],
#        [0.8613986 , 0.87636963, 0.87419992, 0.88504849, 0.88285708],
#        [0.87636963, 0.87419992, 0.88504849, 0.88285708, 0.89155764]])

# %%
y_train
# Out:
# array([0.10497082, 0.10937534, 0.11998525, 0.11310725, 0.11002625,
#        0.10607737, 0.09266853, 0.09301569, 0.09629196, 0.09397036,
#        0.08053983, 0.07036386, 0.07574475, 0.0921912 , 0.1317234 ,
#        0.13519495, 0.13259129, 0.13215735, 0.14491527, 0.14430775,
#        0.14387381, 0.13818916, 0.14127015, 0.14083621, 0.14604352,
#        0.14938489, 0.13604114, 0.1386231 , 0.13736466, 0.12990084,
#        0.12560481, 0.11479963, 0.10998286, 0.10256243, 0.1111979 ,
#        0.10178134, 0.09700796, 0.09744191, 0.10805181, 0.11260821,
#        0.09362321, 0.09692117, 0.09587971, 0.10134739, 0.09527219,
#        0.0822539 , 0.07183927, 0.07980212, 0.0822539 , 0.09223459,
#        0.09492504, 0.10698865, 0.10102194, 0.09574953, 0.09538068,
#        0.10829048, 0.12000694, 0.1317451 , 0.13194038, 0.14506715,
#        0.1515763 , 0.16055892, 0.16036364, 0.17418473, 0.1790015 ,
#        0.17533468, 0.17815531, 0.16687279, 0.17251405, 0.1690425 ,
# ...

# %%
X_train.shape
# Out:
# (780, 5)

# %%
y_train.shape
# Out:
# (780,)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1],1))

# %%
X_train
# Out:
# array([[[0.08353403],
#         [0.09718154],
#         [0.11215257],
#         [0.11234785],
#         [0.11679576]],
#
#        [[0.09718154],
#         [0.11215257],
#         [0.11234785],
#         [0.11679576],
#         [0.10497082]],
#
#        [[0.11215257],
#         [0.11234785],
#         [0.11679576],
#         [0.10497082],
#         [0.10937534]],
#
#        ...,
#
#        [[0.84677472],
#         [0.8613986 ],
#         [0.87636963],
#         [0.87419992],
#         [0.88504849]],
#
#        [[0.8613986 ],
#         [0.87636963],
#         [0.87419992],
#         [0.88504849],
#         [0.88285708]],
#
#        [[0.87636963],
#         [0.87419992],
#         [0.88504849],
#         [0.88285708],
#         [0.89155764]]])

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, GRU, SimpleRNN, Bidirectional
from keras.layers import Dropout

# %%
model_1 = Sequential()
model_1.add(SimpleRNN(units = 50, return_sequences=True, input_shape = (X_train.shape[1],1), activation = 'tanh'))
model_1.add(Dropout(0.2))
model_1.add(SimpleRNN(units = 50, return_sequences=True, input_shape = (X_train.shape[1],1), activation = 'tanh'))
model_1.add(Dropout(0.2))
model_1.add(SimpleRNN(units = 50, return_sequences=True, input_shape = (X_train.shape[1],1), activation = 'tanh'))
model_1.add(Dropout(0.2))
model_1.add(SimpleRNN(units = 50, activation = 'tanh'))
model_1.add(Dropout(0.2))
model_1.add(Dense(units = 1))
model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  simple_rnn (SimpleRNN)      (None, 5, 50)             2600
#
#  dropout (Dropout)           (None, 5, 50)             0
#
#  simple_rnn_1 (SimpleRNN)    (None, 5, 50)             5050
#
#  dropout_1 (Dropout)         (None, 5, 50)             0
#
#  simple_rnn_2 (SimpleRNN)    (None, 5, 50)             5050
#
#  dropout_2 (Dropout)         (None, 5, 50)             0
#
#  simple_rnn_3 (SimpleRNN)    (None, 50)                5050
#
#  dropout_3 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# ...
# Total params: 17801 (69.54 KB)
# Trainable params: 17801 (69.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model_1.compile(optimizer = 'adam', loss= 'mean_squared_error')
model_1.fit(X_train, y_train, epochs = 200, batch_size = 16)
# Out:
# Epoch 1/200
# 49/49 [==============================] - 4s 8ms/step - loss: 0.2492
# Epoch 2/200
# 49/49 [==============================] - 0s 8ms/step - loss: 0.1027
# Epoch 3/200
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0547
# Epoch 4/200
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0400
# Epoch 5/200
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0322
# Epoch 6/200
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0220
# Epoch 7/200
# 49/49 [==============================] - 1s 12ms/step - loss: 0.0226
# Epoch 8/200
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0188
# Epoch 9/200
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0173
# Epoch 10/200
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0144
# Epoch 11/200
# 49/49 [==============================] - 0s 7ms/step - loss: 0.0149
# Epoch 12/200
# ...

# %%
y_train_pred = model_1.predict(X_train)
# Out:
# 25/25 [==============================] - 1s 3ms/step

# %%
from sklearn.metrics import r2_score
r2_score(y_train, y_train_pred)
# Out:
# 0.9932601171649375

# %%
test_set.shape
# Out:
# (316, 1)

# %%
X_test = []
y_test = []

for i in range(5,316):
  X_test.append(scaled_test_set_df.iloc[i-5:i,0])
  y_test.append(scaled_test_set_df.iloc[i,0])

X_test, y_test = np.array(X_test), np.array(y_test)

# %%
X_test
# Out:
# array([[0.13474929, 0.18130063, 0.18773812, 0.19645281, 0.16514123],
#        [0.18130063, 0.18773812, 0.19645281, 0.16514123, 0.18743157],
#        [0.18773812, 0.19645281, 0.16514123, 0.18743157, 0.16203197],
#        ...,
#        [0.80197066, 0.7786293 , 0.80547405, 0.7907598 , 0.76829429],
#        [0.7786293 , 0.80547405, 0.7907598 , 0.76829429, 0.78857018],
#        [0.80547405, 0.7907598 , 0.76829429, 0.78857018, 0.83310707]])

# %%
y_test
# Out:
# array([0.18743157, 0.16203197, 0.20713817, 0.20757609, 0.2329757 ,
#        0.21020363, 0.23542807, 0.25920736, 0.23998248, 0.24668272,
#        0.26800963, 0.29686884, 0.28202321, 0.29165754, 0.30256186,
#        0.29428509, 0.26800963, 0.31180206, 0.34245675, 0.31543683,
#        0.33282242, 0.37389972, 0.38064375, 0.37604554, 0.38186994,
#        0.3607182 , 0.36172542, 0.404642  , 0.37302387, 0.35822203,
#        0.34674841, 0.29253339, 0.29726297, 0.28110357, 0.24261003,
#        0.24436173, 0.24173418, 0.22500547, 0.21458288, 0.25570396,
#        0.24786512, 0.23823079, 0.19640902, 0.22491789, 0.1676374 ,
#        0.12905627, 0.09354062, 0.09494198, 0.04961682, 0.03831837,
#        0.02671338, 0.02920955, 0.04992336, 0.03481498, 0.03201226,
#        0.03240639, 0.08758485, 0.09805124, 0.13255967, 0.12642873,
#        0.13925991, 0.14009196, 0.12958178, 0.10247427, 0.04414276,
#        0.03840596, 0.02364791, 0.        , 0.0450624 , 0.0595139 ,
# ...

# %%
X_test.shape
# Out:
# (311, 5)

# %%
y_test.shape
# Out:
# (311,)

# %%
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1],1))

# %%
y_test_pred = model_1.predict(X_test)
# Out:
# 10/10 [==============================] - 0s 3ms/step

# %%
r2_score(y_test, y_test_pred)
# Out:
# 0.9757073365595695

# %%
results_train = pd.DataFrame()
results_train['actual'] = y_train
results_train['pred'] = y_train_pred

# %%
results_train.plot()
# Out:
# <Axes: >

# %%
results_test = pd.DataFrame()
results_test['actual'] = y_test
results_test['pred'] = y_test_pred

# %%
results_test.plot()
# Out:
# <Axes: >

# %%
model_2 = Sequential()
model_2.add(LSTM(units = 50 , return_sequences = True, input_shape = (X_train.shape[1], 1),activation = 'tanh'))
model_2.add(LSTM(units = 50, return_sequences = True,input_shape = (X_train.shape[1], 1),activation = 'tanh' ))
model_2.add(LSTM(units = 50, return_sequences = True,input_shape = (X_train.shape[1], 1),activation = 'tanh'))
model_2.add(LSTM(units = 50, return_sequences = True,input_shape = (X_train.shape[1], 1),activation = 'tanh'))
model_2.add(LSTM(units = 50))
model_2.add(Dense(units = 1))
model_2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 5, 50)             10400
#
#  lstm_1 (LSTM)               (None, 5, 50)             20200
#
#  lstm_2 (LSTM)               (None, 5, 50)             20200
#
#  lstm_3 (LSTM)               (None, 5, 50)             20200
#
#  lstm_4 (LSTM)               (None, 50)                20200
#
#  dense_1 (Dense)             (None, 1)                 51
#
# ...
# Total params: 91251 (356.45 KB)
# Trainable params: 91251 (356.45 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model_2.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
model_2.fit(X_train, y_train, epochs = 200, batch_size = 16)
# Out:
# Epoch 1/200
# 49/49 [==============================] - 9s 15ms/step - loss: 0.0658
# Epoch 2/200
# 49/49 [==============================] - 1s 15ms/step - loss: 0.0021
# Epoch 3/200
# 49/49 [==============================] - 1s 14ms/step - loss: 0.0011
# Epoch 4/200
# 49/49 [==============================] - 1s 18ms/step - loss: 0.0011
# Epoch 5/200
# 49/49 [==============================] - 1s 21ms/step - loss: 0.0011
# Epoch 6/200
# 49/49 [==============================] - 1s 23ms/step - loss: 0.0011
# Epoch 7/200
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0013
# Epoch 8/200
# 49/49 [==============================] - 1s 14ms/step - loss: 0.0012
# Epoch 9/200
# 49/49 [==============================] - 1s 14ms/step - loss: 0.0015
# Epoch 10/200
# 49/49 [==============================] - 1s 14ms/step - loss: 0.0011
# Epoch 11/200
# 49/49 [==============================] - 1s 14ms/step - loss: 0.0011
# Epoch 12/200
# ...

# %%
y_train_pred2 = model_2.predict(X_train)
# Out:
# 25/25 [==============================] - 3s 8ms/step

# %%
y_test_pred2 = model_2.predict(X_test)
# Out:
# 10/10 [==============================] - 0s 5ms/step

# %%
r2_score(y_train,y_train_pred2)
# Out:
# 0.9967111721147938

# %%
r2_score(y_test,y_test_pred2)
# Out:
# 0.9822199192500306

# %%
results_train2 = pd.DataFrame()
results_train2['actual'] = y_train
results_train2['pred'] = y_train_pred2

# %%
results_train2.plot()
# Out:
# <Axes: >

# %%
results_test2 = pd.DataFrame()
results_test2['actual'] = y_test
results_test2['pred'] = y_test_pred2

# %%
results_test2.plot()
# Out:
# <Axes: >

# %%
model_3 = Sequential()

model_3.add(GRU(50, return_sequences= True, input_shape = (X_train.shape[1],1), activation = 'tanh'))
model_3.add(Dropout(0.2))
model_3.add(GRU(50,return_sequences= True, input_shape = (X_train.shape[1],1), activation = 'tanh'))
model_3.add(Dropout(0.2))
model_3.add(GRU(50,return_sequences= True, input_shape = (X_train.shape[1],1), activation = 'tanh'))
model_3.add(Dropout(0.2))
model_3.add(GRU(50, activation = 'tanh'))
model_3.add(Dropout(0.2))
model_3.add(Dense(units = 1))
model_3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  gru (GRU)                   (None, 5, 50)             7950
#
#  dropout_4 (Dropout)         (None, 5, 50)             0
#
#  gru_1 (GRU)                 (None, 5, 50)             15300
#
#  dropout_5 (Dropout)         (None, 5, 50)             0
#
#  gru_2 (GRU)                 (None, 5, 50)             15300
#
#  dropout_6 (Dropout)         (None, 5, 50)             0
#
#  gru_3 (GRU)                 (None, 50)                15300
#
#  dropout_7 (Dropout)         (None, 50)                0
#
#  dense_2 (Dense)             (None, 1)                 51
#
# ...
# Total params: 53901 (210.55 KB)
# Trainable params: 53901 (210.55 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model_3.compile(optimizer = 'adam', loss = 'mean_squared_error')
model_3.fit(X_train, y_train, epochs = 200, batch_size = 16)
# Out:
# Epoch 1/200
# 49/49 [==============================] - 10s 12ms/step - loss: 0.0309
# Epoch 2/200
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0050
# Epoch 3/200
# 49/49 [==============================] - 1s 19ms/step - loss: 0.0044
# Epoch 4/200
# 49/49 [==============================] - 1s 19ms/step - loss: 0.0041
# Epoch 5/200
# 49/49 [==============================] - 1s 19ms/step - loss: 0.0036
# Epoch 6/200
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0040
# Epoch 7/200
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0030
# Epoch 8/200
# 49/49 [==============================] - 1s 12ms/step - loss: 0.0030
# Epoch 9/200
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0028
# Epoch 10/200
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0025
# Epoch 11/200
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0027
# Epoch 12/200
# ...

# %%
y_train_pred3 = model_3.predict(X_train)
# Out:
# 25/25 [==============================] - 1s 4ms/step

# %%
y_test_pred3 = model_3.predict(X_test)
# Out:
# 10/10 [==============================] - 0s 5ms/step

# %%
r2_score(y_train,y_train_pred3)
# Out:
# 0.9962497417758274

# %%
r2_score(y_test,y_test_pred3)
# Out:
# 0.9795625567313849

# %%
results_train3 = pd.DataFrame()
results_train3['actual'] = y_train
results_train3['pred'] = y_train_pred3

# %%
results_train3.plot()
# Out:
# <Axes: >

# %%
results_test3 = pd.DataFrame()
results_test3['actual'] = y_test
results_test3['pred'] = y_test_pred3

# %%
results_test3.plot()
# Out:
# <Axes: >

# %%
model_4 = Sequential()

model_4.add(Bidirectional(SimpleRNN(50)))
model_4.add(Dense(1, activation='tanh'))

# %%
model_4.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
model_4.fit(X_train, y_train, epochs = 200, batch_size = 16)
# Out:
# Epoch 1/200
# 49/49 [==============================] - 2s 4ms/step - loss: 0.0168
# Epoch 2/200
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0027
# Epoch 3/200
# 49/49 [==============================] - 0s 4ms/step - loss: 0.0023
# Epoch 4/200
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0021
# Epoch 5/200
# 49/49 [==============================] - 0s 4ms/step - loss: 0.0019
# Epoch 6/200
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 7/200
# 49/49 [==============================] - 0s 4ms/step - loss: 0.0016
# Epoch 8/200
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0014
# Epoch 9/200
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0011
# Epoch 10/200
# 49/49 [==============================] - 0s 6ms/step - loss: 9.6731e-04
# Epoch 11/200
# 49/49 [==============================] - 0s 7ms/step - loss: 8.1653e-04
# Epoch 12/200
# ...

# %%
y_test_pred4 = model_4.predict(X_test)
# Out:
# 10/10 [==============================] - 0s 2ms/step

# %%
y_train_pred4 = model_4.predict(X_train)
# Out:
# 25/25 [==============================] - 0s 2ms/step

# %%
from sklearn.metrics import r2_score
r2_score(y_train,y_train_pred4)
# Out:
# 0.9957621868769732

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_test_pred4)
# Out:
# 0.9810382280114227

# %%
results_train4 = pd.DataFrame()
results_train4['actual'] = y_train
results_train4['pred'] = y_train_pred4

results_train4.plot()
# Out:
# <Axes: >

# %%
results_train4 = pd.DataFrame()
results_train4['actual'] = y_train
results_train4['pred'] = y_train_pred4

results_train4.plot()
# Out:
# <Axes: >

# %%
results_test4 = pd.DataFrame()
results_test4['actual'] = y_test
results_test4['pred'] = y_test_pred4

# %%
results_test4.plot()
# Out:
# <Axes: >
